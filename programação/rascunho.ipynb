# %%
from tcc_funcoes import *
# Out:
# =================================== Módulo importado com sucesso ===================================

# %%
dc_treino = abre_arquivo_pickle('dc_treino.pkl')
dc_teste = abre_arquivo_pickle('dc_teste.pkl')

# %%
for nome, dc in dc_treino.items():

    for k, v in dc.items():

        print(f'{nome} {k} treino: {v.shape}')

for nome, dc in dc_teste.items():

    for k, v in dc.items():

        print(f'{nome} {k} teste: {v.shape}')
# Out:
# Ciências Humanas x treino: (6300397, 29)
# Ciências Humanas y treino: (6300397, 1)
# Ciências Natureza x treino: (5960826, 29)
# Ciências Natureza y treino: (5960826, 1)
# Linguagem e Código x treino: (6287276, 29)
# Linguagem e Código y treino: (6287276, 1)
# Matemática x treino: (5977684, 29)
# Matemática y treino: (5977684, 1)
# Redação x treino: (6090031, 29)
# Redação y treino: (6090031, 1)
# Ciências Humanas x teste: (1575100, 29)
# Ciências Humanas y teste: (1575100, 1)
# Ciências Natureza x teste: (1490207, 29)
# Ciências Natureza y teste: (1490207, 1)
# Linguagem e Código x teste: (1571819, 29)
# Linguagem e Código y teste: (1571819, 1)
# Matemática x teste: (1494422, 29)
# Matemática y teste: (1494422, 1)
# Redação x teste: (1522508, 29)
# Redação y teste: (1522508, 1)
